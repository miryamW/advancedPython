# %%
arr = np.array(1,2,3)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 arr = np.array(1,2,3)
#       2 arr
#
# NameError: name 'np' is not defined

# %%
arr = [1,2,3,4]
arr
# Out:
# [1, 2, 3, 4]

# %%
my_arr = np.array(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 my_arr = np.array(arr)
#
# NameError: name 'np' is not defined

# %%
pip install numpy
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.2 kB ? eta -:--:--
#      -------------------------------------- 61.2/61.2 kB 809.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 435.7 kB/s eta 0:00:37
#    ---------------------------------------- 0.0/15.8 MB 435.7 kB/s eta 0:00:37
#    ---------------------------------------- 0.0/15.8 MB 435.7 kB/s eta 0:00:37
#    ---------------------------------------- 0.0/15.8 MB 196.9 kB/s eta 0:01:21
#    ---------------------------------------- 0.1/15.8 MB 504.4 kB/s eta 0:00:32
#    ---------------------------------------- 0.1/15.8 MB 504.4 kB/s eta 0:00:32
#    ---------------------------------------- 0.1/15.8 MB 426.7 kB/s eta 0:00:37
#    ---------------------------------------- 0.2/15.8 MB 535.8 kB/s eta 0:00:30
# ...

# %%
import numpy as np

# %%
my_arr = np.array(arr)

# %%
my_arr
# Out:
# array([1, 2, 3, 4])

# %%
my_arr.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 my_arr.dtype()
#
# TypeError: 'numpy.dtypes.Int32DType' object is not callable

# %%
my_arr.dtype
# Out:
# dtype('int32')

# %%
random_int_array = np.random.randint(1, 50, size=(10))

# %%
random_int_array
# Out:
# array([48, 18, 40, 49, 41,  3, 15, 10, 12, 27])

# %%
random_int_array.size
# Out:
# 10

# %%
random_int_array.dtype
# Out:
# dtype('int32')

# %%
np.ndim(random_int_array)
# Out:
# 1

# %%
two_dims_array = np..random.randint(10,100, size =(2,5))
# Out:
#   Cell In[15], line 1
#     two_dims_array = np..random.randint(10,100, size =(2,5))
#                         ^
# SyntaxError: invalid syntax

# %%
two_dims_array = np.random.randint(10,100, size =(2,5))

# %%
two_dims_array
# Out:
# array([[53, 84, 23, 33, 55],
#        [56, 22, 95, 75, 13]])

# %%
two_dims_array.shape
# Out:
# (2, 5)
