# %%
pip install numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 330.3 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 546.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB 653.6 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/15.8 MB 469.7 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/15.8 MB 853.3 kB/s eta 0:00:19
#    ---------------------------------------- 0.2/15.8 MB 807.1 kB/s eta 0:00:20
#     --------------------------------------- 0.2/15.8 MB 734.2 kB/s eta 0:00:22
# ...

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50, size=10)

# %%
random_int_array
# Out:
# array([43, 34,  7, 42, 18, 22, 44, 34, 32, 28])

# %%
np.mean(random_int_array)
# Out:
# 30.4

# %%
three_1 =  np.random.randint(1, 100, size=(3,3))

# %%
three_2 = np.random.randint(1, 100, size=(3,3))

# %%
three = np.add(three_1,three_2)

# %%
three_1
# Out:
# array([[47, 50, 26],
#        [37, 68, 99],
#        [34, 55, 34]])

# %%
three_2
# Out:
# array([[48, 94, 94],
#        [78, 75, 84],
#        [44, 94, 96]])

# %%
three
# Out:
# array([[ 95, 144, 120],
#        [115, 143, 183],
#        [ 78, 149, 130]])

# %%
np.mean(three)
# Out:
# 128.55555555555554

# %%
twenty =  np.random.randint(1, 100, size=20)

# %%
cond = twenty > 50
bigger_50 = twenty[cond]

# %%
bigger_50
# Out:
# array([86, 52, 80, 54, 74, 53, 52, 62, 62, 70, 99, 55])

# %%
ten =  np.random.randint(1, 100, size=20)

# %%
np.random.shuffle(ten)

# %%
ten
# Out:
# array([11, 12, 85,  2, 95, 65, 23, 61, 57,  2, 84, 23, 79, 93, 86, 12, 14,
#        75,  6, 48])

# %%
ten[np.random.randint(1,10)]
# Out:
# 85

# %%
ten[np.random.randint(1,10)]
# Out:
# 2
